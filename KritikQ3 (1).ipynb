# %%
import numpy as np

def central_difference_derivative(f, c):
    return (f(c + 10**-8) - f(c - 10**-8)) / (2 * 10**-8)

def linear_approximation(f, c, x):
    f_prime = central_difference_derivative(f, c)
    return f(c) + f_prime * (x - c)

def find_x1_x2(f, c, E, max_iter=10000, search_range=10):
    f_prime = central_difference_derivative(f, c)
    L = lambda x: linear_approximation(f, c, x)
    
    x1, x2 = None, None
    step_size = 10**-8
    
    for i in range(1, max_iter):
        x_left = c - i * step_size
        if abs(f(x_left) - L(x_left)) >= E:
            x1 = x_left
            break
    
    for i in range(1, max_iter):
        x_right = c + i * step_size
        if abs(f(x_right) - L(x_right)) >= E:
            x2 = x_right
            break
    
    if x1 is not None and x2 is not None:
        return x1, x2
    else:
        return "No value was found within a reasonable range"

f = lambda x: x**2
c = 1
E = 0.1

result = find_x1_x2(f, c, E)
print(result)
# Out:
# No value was found within a reasonable range

# %%
import numpy as np



def central_difference_derivative(f, c):
    return (f(c + 10**-8) - f(c - 10**-8)) / (2 * 10**-8)

def linear_approximation(f, c, x):
    f_prime = central_difference_derivative(f, c)
    return f(c) + f_prime * (x - c)

def find_x1_x2(f, c, E, max_iter=10000, search_range=50):
    f_prime = central_difference_derivative(f, c)
    L = lambda x: linear_approximation(f, c, x)
    
    x1, x2 = None, None
    step_size = 10**-8
    
    for i in range(1, max_iter):
        x_left = c - i * step_size
        if abs(f(x_left) - L(x_left)) >= E:
            x1 = x_left
            break
    
    for i in range(1, max_iter):
        x_right = c + i * step_size
        if abs(f(x_right) - L(x_right)) >= E:
            x2 = x_right
            break
    
    if x1 is not None and x2 is not None:
        return x1, x2
    else:
        return "No value was found within a reasonable range"

f = lambda x: np.sin(x)
c = np.pi/4
E = 0.05

result = find_x1_x2(f, c, E)
print(result)

result = find_x1_x2(f, c, E)
print(result)
# Out:
# No value was found within a reasonable range
# No value was found within a reasonable range

# %%
import numpy as np



def central_difference_derivative(f, c):
    return (f(c + 10**-8) - f(c - 10**-8)) / (2 * 10**-8)

def linear_approximation(f, c, x):
    f_prime = central_difference_derivative(f, c)
    return f(c) + f_prime * (x - c)

def find_x1_x2(f, c, E, max_iter=10000, search_range=50):
    f_prime = central_difference_derivative(f, c)
    L = lambda x: linear_approximation(f, c, x)
    
    x1, x2 = None, None
    step_size = 10**-8
    
    for i in range(1, max_iter):
        x_left = c - i * step_size
        if abs(f(x_left) - L(x_left)) >= E:
            x1 = x_left
            break
    
    for i in range(1, max_iter):
        x_right = c + i * step_size
        if abs(f(x_right) - L(x_right)) >= E:
            x2 = x_right
            break
    
    if x1 is not None and x2 is not None:
        return x1, x2
    else:
        return "No value was found within a reasonable range"

f = lambda x: np.exp(x)
c = 0
E = 0.01

result = find_x1_x2(f, c, E)
print(result)
# Out:
# No value was found within a reasonable range

# %%
import numpy as np



def central_difference_derivative(f, c):
    return (f(c + 10**-8) - f(c - 10**-8)) / (2 * 10**-8)

def linear_approximation(f, c, x):
    f_prime = central_difference_derivative(f, c)
    return f(c) + f_prime * (x - c)

def find_x1_x2(f, c, E, max_iter=10000, search_range=50):
    f_prime = central_difference_derivative(f, c)
    L = lambda x: linear_approximation(f, c, x)
    
    x1, x2 = None, None
    step_size = 10**-8
    
    for i in range(1, max_iter):
        x_left = c - i * step_size
        if abs(f(x_left) - L(x_left)) >= E:
            x1 = x_left
            break
    
    for i in range(1, max_iter):
        x_right = c + i * step_size
        if abs(f(x_right) - L(x_right)) >= E:
            x2 = x_right
            break
    
    if x1 is not None and x2 is not None:
        return x1, x2
    else:
        return "No value was found within a reasonable range"

f = lambda x: np.exp**x
c = 0
E = 0.01

result = find_x1_x2(f, c, E)
print(result)
